# %%
# Check out all the movies and their respective IDs
import pandas as pd
import sklearn
movie_titles = pd.read_csv('https://media.geeksforgeeks.org/wp-content/uploads/Movie_Id_Titles.csv')
movcopy=movie_titles.copy()
movcopy.tail()
# Out:
#       item_id                                      title
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)

# %%
column_names = ['user_id', 'item_id', 'rating', 'timestamp']

path = 'https://media.geeksforgeeks.org/wp-content/uploads/file.tsv'

df = pd.read_csv(path, sep='\t', names=column_names)

# Check the head of the data
df.tail()
import random

# %%
data = pd.merge(df, movie_titles, on='item_id')
data.to_csv('data.csv')
data.tail()
# Out:
#         user_id  item_id  rating  timestamp  \
# 99998       840     1674       4  891211682
# 99999       655     1640       3  888474646
# 100000      655     1637       3  888984255
# 100001      655     1630       3  887428735
# 100002      655     1641       3  887427810
#
#                                                     title
# 99998                                   Mamma Roma (1962)
# 99999                              Eighth Day, The (1996)
# 100000                                  Girls Town (1996)
# 100001  Silence of the Palace, The (Saimt el Qusur) (1...
# 100002                                    Dadetown (1995)

# %%
# Calculate mean rating of all movies
data.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# They Made Me a Criminal (1939)                5.0
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Saint of Fort Washington, The (1993)          5.0
# Someone Else's America (1995)                 5.0
# Star Kid (1997)                               5.0
# Name: rating, dtype: float64

# %%
# creating dataframe with 'rating' count values
ratings = pd.DataFrame(data.groupby(['title'])['rating'].mean())
ratings['num of ratings'] = pd.DataFrame(data.groupby('title')['rating'].count())
ratings.to_csv('checker.csv')
ratings.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %%
# Sorting values according to
# the 'num of rating column'
moviemat = data.pivot_table(index ='user_id',columns ='title', values ='rating')

#moviemat.head(10)
avg_ratings=ratings.sort_values('num of ratings', ascending = False).head()
#Now CSV
#
#
ratings = pd.read_csv('checker.csv')
avg_ratings=ratings.sort_values('num of ratings', ascending = True)
avg_ratings.to_csv('averageratings.csv')
avg_ratings=pd.read_csv('averageratings.csv')
df = pd.read_csv("data.csv")
def dcg_score(mylist):
    mylist = [x for x in mylist if str(x) != 'nan']
    for i in range(0,len(mylist)):
        mylist[i]=mylist[i]*(100)
    for i in range(0,3):
        mylist.append(10*random.random())
    return mylist
df_merged = ratings.merge(df,on='title',how='inner')
df_merged.to_csv("Final.csv")

# %%
value=input("Enter the name of the movie: ")
moviemat.head()
value_user_ratings=moviemat[value]
value_user_ratings.head(10)
# Out:
# Enter the name of the movie: 101 Dalmatians (1996)
# user_id
# 0    NaN
# 1    2.0
# 2    NaN
# 3    NaN
# 4    NaN
# 5    2.0
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: 101 Dalmatians (1996), dtype: float64

# %%
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
# analysing correlation with similar movies
similar_to_value = moviemat.corrwith(value_user_ratings)

corr_value = pd.DataFrame(similar_to_value, columns =['Correlation'])
corr_value.dropna(inplace = True)

corr_value.head(1500)
# Out:
# /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                        Correlation
# title
# 'Til There Was You (1997)                -1.000000
# 101 Dalmatians (1996)                     1.000000
# 12 Angry Men (1957)                      -0.049890
# 187 (1997)                                0.269191
# 2 Days in the Valley (1996)               0.048973
# ...                                            ...
# Young Frankenstein (1974)                 0.158840
# Young Guns (1988)                         0.119234
# Young Guns II (1990)                      0.680414
# Young Poisoner's Handbook, The (1995)     0.000000
# Zeus and Roxanne (1997)                   0.707107
#
# [1118 rows x 1 columns]

# %%
# Similar movies like input
corr_value.sort_values('Correlation', ascending = False).head(10)
#corr_value = corr_value.join(ratings['num of ratings'])
corr_value.sort_values(by=['Correlation'], ascending=False).head(1662)
#corr_value.head()

#corr_value[corr_value['num of ratings']>100].sort_values('Correlation', ascending = False).head()
# Out:
#                                                     Correlation
# title
# Hard Rain (1998)                                            1.0
# Winter Guest, The (1997)                                    1.0
# Fatal Instinct (1993)                                       1.0
# Faithful (1996)                                             1.0
# Trial by Jury (1994)                                        1.0
# ...                                                         ...
# Unhook the Stars (1996)                                    -1.0
# Warriors of Virtue (1997)                                  -1.0
# Unstrung Heroes (1995)                                     -1.0
# Until the End of the World (Bis ans Ende der We...         -1.0
# Robocop 3 (1993)                                           -1.0
#
# [1118 rows x 1 columns]

# %%
group_users = []
n = int(input("Enter number of member in the group : "))
# iterating till the range
for i in range(0, n):
   print("Enter Userid No-{}: ".format(i+1))
   elm = int(input())
   group_users.append(elm) # adding the element
print("The entered list is: \n",group_users)
# Out:
# Enter number of member in the group : 3
# Enter Userid No-1:
# 2
# Enter Userid No-2:
# 3
# Enter Userid No-3:
# 4
# The entered list is:
#  [2, 3, 4]

# %%
data.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import csv
myfinal_list=[]
temp1=[]
my_list=[]
sum=0
numoffilms=0
x = pd.read_csv("Final.csv")
n=len(x)
n_movies = len(x['item_id'].unique())
print(f'Movies - : {n_movies}')
print(f"Total - : {n}")

ratinglist=[]
# Out:
# Movies - : 1682
# Total - : 100003

# %%
with open('Final.csv', 'r') as df:
  mycsv = csv.reader(df)
  mycsv = list(mycsv)
  cnt = 1
  temp = int(mycsv[1][3])
  i = 1
  while(i < n):
    my_list.append(mycsv[i][1])
    i = i+int(mycsv[i][3])

# %%
with open('Final.csv', 'r') as df:
  mycsv = csv.reader(df)
  mycsv = list(mycsv)
  i = 1
  movieid = mycsv[1][6]
  #print(movieid)
  num = mycsv[1][3]
  #####
  #print(my_list)
  #####
  checker = int(mycsv[1][3])
  x = 1
  breakpoints = []
  while(x < n):
    if x >= checker:
      breakpoints.append(checker)
      checker += int(mycsv[x+1][3])
    x = x+1
  print(breakpoints)
# Out:
# [9, 14, 123, 248, 289, 382, 454, 713, 718, 777, 815, 819, 823, 831, 836, 963, 1114, 1217, 1254, 1258, 1345, 1399, 1410, 1449, 1560, 1627, 1653, 1805, 1823, 1888, 1889, 1932, 2363, 2379, 2411, 2461, 2680, 2706, 2719, 2725, 2806, 3097, 3197, 3321, 3605, 3671, 3686, 3689, 3690, 3702, 3978, 3996, 4006, 4017, 4019, 4183, 4185, 4284, 4334, 4458, 4463, 4469, 4473, 4526, 4540, 4545, 4548, 4567, 4571, 4609, 4675, 4693, 4697, 4703, 4704, 4705, 4777, 4816, 4830, 4832, 4865, 4886, 5066, 5094, 5163, 5170, 5233, 5454, 5730, 5785, 5810, 5825, 5985, 6039, 6155, 6214, 6297, 6412, 6524, 6563, 6581, 6622, 6634, 6635, 6765, 6773, 6780, 6783, 6784, 7003, 7013, 7015, 7018, 7368, 7387, 7444, 7453, 7459, 7465, 7481, 7485, 7501, 7558, 7567, 7597, 7625, 7678, 7779, 7819, 7863, 7879, 7941, 8142, 8256, 8398, 8399, 8490, 8492, 8499, 8585, 8700, 8729, 8931, 9087, 9147, 9204, 9253, 9279, 9289, 9293, 9409, 9425, 9462, 9586, 9688, 9694, 9699, 9705, 9784, 9804, 9832, 9880, 9883, 9885, 9903, 9911, 9912, 9929, 9943, 99
# ...

# %%
with open('Final.csv','r') as df:
  mycsv = csv.reader(df)
  mycsv = list(mycsv)
  num=0
  while(i<n):
    if i<breakpoints[num]:
      for it in range(0,len(group_users)):
        #print(gp, mycsv[i][5])
        if group_users[it]==int(mycsv[i][5]):
          temp1.append(int(mycsv[i][7]))
    else:
      for j in range(0,(len(group_users)-len(temp1))):
        temp1.append(0)
      #print(temp1)
      ratinglist.extend(temp1)
      temp1.clear()
      num+=1
    i+=1
num=0

# %%
tempCSVfile = []
#numofpeople=[]*(len(group_users)+1)
numofpeople = []
colname='A'
numofpeople = ['title']
for iterator in range (0,len(group_users)):
  numofpeople.append(chr(ord(colname) + iterator))
with open("FinalCSVfile.csv", 'w') as csvfinalfile:
    csvwriter = csv.writer(csvfinalfile)
    csvwriter.writerow(numofpeople)

for i in range(0, len(my_list)):
  tempCSVfile.append(my_list[i])
  for j in range (0,len(group_users)):
    tempCSVfile.append(ratinglist[i+j])
  #print(tempCSVfile)

  with open("FinalCSVfile.csv", 'a') as csvfinalfile:
    csvwriter = csv.writer(csvfinalfile)
    csvwriter.writerow(tempCSVfile)
  tempCSVfile.clear()

# %%
#Average Strategy
df = pd.read_csv('FinalCSVfile.csv')
colname='A'
sumrow=0
for i in range (0,len(group_users)):
    sumrow=sumrow+df[str(chr(ord(colname) + i))]
df['Average']=(sumrow/len(group_users)).round(3)
df.sort_values(by=['Average'], ascending=False).head(1000)
# Out:
#                                                   title  A  B  C  Average
# 1221                               Red Rock West (1992)  4  5  4    4.333
# 96                                  Arrival, The (1996)  2  5  4    3.667
# 999                                Mortal Kombat (1995)  3  5  2    3.333
# 1222                                    Ref, The (1994)  5  4  0    3.000
# 1017                            Mulholland Falls (1996)  4  5  0    3.000
# ...                                                 ... .. .. ..      ...
# 427                                   Doors, The (1991)  0  0  0    0.000
# 426                         Doom Generation, The (1995)  0  0  0    0.000
# 425                                Donnie Brasco (1997)  0  0  0    0.000
# 424   Don't Be a Menace to South Central While Drink...  0  0  0    0.000
# 423                             Don Juan DeMarco (1995)  0  0  0    0.000
#
# [1000 rows x 5 columns]

# %%
#least misery
maxratingoutofbond=6
lm=0
df['Least Misery'] = df.min(axis=1)
df.sort_values(by=['Least Misery'], ascending=False).head(15)
# Out:
# <ipython-input-480-521a81b906f5>:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Least Misery'] = df.min(axis=1)
#                                  title  A  B  C  Average  Least Misery
# 1221              Red Rock West (1992)  4  5  4    4.333           4.0
# 96                 Arrival, The (1996)  2  5  4    3.667           2.0
# 999               Mortal Kombat (1995)  3  5  2    3.333           2.0
# 1105                Open Season (1996)  0  0  0    0.000           0.0
# 1115            Pagemaster, The (1994)  0  0  0    0.000           0.0
# 1114                Outlaw, The (1943)  0  0  0    0.000           0.0
# 1113                   Outbreak (1995)  0  0  0    0.000           0.0
# 1112                 Out to Sea (1997)  0  0  0    0.000           0.0
# ...

# %%
#most pleasure
colname='A'
maxratingoutofbond=6
lm=0
df['Most Pleasure'] = df.max(axis=1)
df.sort_values(by=['Most Pleasure'], ascending=False).head(15)
# Out:
# <ipython-input-481-40ed7e615eea>:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Most Pleasure'] = df.max(axis=1)
#                                            title  A  B  C  Average  \
# 620                          Good Morning (1971)  0  5  0    1.667
# 1017                     Mulholland Falls (1996)  4  5  0    3.000
# 1363                      Sophie's Choice (1982)  0  0  5    1.667
# 1364                            Soul Food (1997)  0  5  0    1.667
# 1365                  Sound of Music, The (1965)  5  0  0    1.667
# 592                        Get on the Bus (1996)  0  0  5    1.667
# 298                     Chungking Express (1994)  0  0  5    1.667
# 1018                         Multiplicity (1996)  5  0  0    1.667
# 593                          Getaway, The (1994)  0  5  0    1.667
# ...

# %%
#Most Respected
#Assuming that the people are taken in the group according to seniority..
colname='A'
maxratingoutofbond=6
df['Most Respected'] = df['A']
df.sort_values(by=['Most Respected'], ascending=False).head(15)
# Out:
#                                            title  A  B  C  Average  \
# 996       Monty Python and the Holy Grail (1974)  5  3  0    2.667
# 1494                         Time Tracers (1995)  5  0  0    1.667
# 1222                             Ref, The (1994)  5  4  0    3.000
# 300                            Cinderella (1950)  5  0  0    1.667
# 1365                  Sound of Music, The (1965)  5  0  0    1.667
# 594              Getting Away With Murder (1996)  5  0  0    1.667
# 97                   Arsenic and Old Lace (1944)  5  4  0    3.000
# 294   Children of the Corn: The Gathering (1996)  5  0  0    1.667
# 1018                         Multiplicity (1996)  5  0  0    1.667
# 621                     Good Will Hunting (1997)  5  0  0    1.667
# 1000          Mortal Kombat: Annihilation (1997)  5  2  0    2.333
# 1359               Someone Else's America (1995)  4  0  0    1.333
# 534                Flirting With Disaster (1996)  4  0  0    1.333
# ...

# %%
#Multiplicative
colname='A'
maxratingoutofbond=6
mul=1
for i in range (0,len(group_users)):
    mul=mul*df[str(chr(ord(colname) + i))]
df['Multiplicative'] = mul
df.sort_values(by=['Multiplicative'], ascending=False).head(15)
# Out:
#                                  title  A  B  C  Average  Least Misery  \
# 1221              Red Rock West (1992)  4  5  4    4.333           4.0
# 96                 Arrival, The (1996)  2  5  4    3.667           2.0
# 999               Mortal Kombat (1995)  3  5  2    3.333           2.0
# 1105                Open Season (1996)  0  0  0    0.000           0.0
# 1115            Pagemaster, The (1994)  0  0  0    0.000           0.0
# 1114                Outlaw, The (1943)  0  0  0    0.000           0.0
# 1113                   Outbreak (1995)  0  0  0    0.000           0.0
# 1112                 Out to Sea (1997)  0  0  0    0.000           0.0
# 1111  Other Voices, Other Rooms (1997)  0  0  0    0.000           0.0
# 1110                    Othello (1995)  0  0  0    0.000           0.0
# 1109            Oscar & Lucinda (1997)  0  0  0    0.000           0.0
# 1108                    Orlando (1993)  0  0  0    0.000           0.0
# ...

# %%
#Average without misery
colname='A'
sumrow=0
counter=0
cnvtlist=[]
for j in range (0,len(df)):
    counter=0
    sumrow=0
    for i in range (0,len(group_users)):
        pos=str(chr(ord(colname) + i))
        value = df.at[j,pos]
        if(value>1):
            sumrow=sumrow+value
            counter=counter+1
    if(counter>0):
        cnvtlist.append(sumrow/counter)
    else:
        cnvtlist.append(0)
ser = pd.Series(cnvtlist)
df['Average Without misery']=ser
df.sort_values(by=['Average Without misery'],ascending=False).head(1663)
# Out:
#                                            title  A  B  C  Average  \
# 294   Children of the Corn: The Gathering (1996)  5  0  0    1.667
# 1494                         Time Tracers (1995)  5  0  0    1.667
# 619                 Good Man in Africa, A (1994)  0  0  5    1.667
# 292                               Chasers (1994)  0  0  5    1.667
# 293                           Chasing Amy (1997)  0  5  0    1.667
# ...                                          ... .. .. ..      ...
# 571                     Full Metal Jacket (1987)  0  0  0    0.000
# 570                         Fugitive, The (1993)  0  0  0    0.000
# 569                   From Dusk Till Dawn (1996)  0  0  0    0.000
# 568                                 Frisk (1995)  0  0  0    0.000
# 1662                                     unknown  0  0  0    0.000
#
#       Least Misery  Most Pleasure  Most Respected  Multiplicative  \
# 294            0.0            5.0               5               0
# ...

# %%
#Approval Voting
colname='A'
counter=0
newlist=[]
for j in range (0,len(df)):
    counter=0
    for i in range (0,len(group_users)):
        pos=str(chr(ord(colname) + i))
        value = df.at[j,pos]
        if(value>2):
            counter=counter+1
    if(counter>0):
        newlist.append(counter)
    else:
        newlist.append(0)
ser = pd.Series(newlist)
df['Approval Voting']=ser
df.sort_values(by=['Approval Voting'],ascending=False).head(10)
# Out:
#                                        title  A  B  C  Average  Least Misery  \
# 1221                    Red Rock West (1992)  4  5  4    4.333           4.0
# 996   Monty Python and the Holy Grail (1974)  5  3  0    2.667           0.0
# 998           Moonlight and Valentino (1995)  0  3  5    2.667           0.0
# 1230         Replacement Killers, The (1998)  3  3  0    2.000           0.0
# 1229                       Rent-a-Kid (1995)  0  3  3    2.000           0.0
# 995              Month by the Lake, A (1995)  0  5  3    2.667           0.0
# 1016           Much Ado About Nothing (1993)  0  4  5    3.000           0.0
# 96                       Arrival, The (1996)  2  5  4    3.667           2.0
# 97               Arsenic and Old Lace (1944)  5  4  0    3.000           0.0
# 1017                 Mulholland Falls (1996)  4  5  0    3.000           0.0
#
#       Most Pleasure  Most Respected  Multiplicative  Average Without misery  \
# ...

# %%
#Copeland rule
colname='A'
newlist=[]
for j in range (0,len(df)):

    for i in range (0,len(group_users)):
        pos1=str(chr(ord(colname) + i))
        val1 = df.at[j,pos1]
        beats = 0
        lose = 0
        for k in range (0,len(group_users)):
           pos2=str(chr(ord(colname) + k))
           val2 = df.at[j,pos2]
           if(val1 > val2):
             beats = beats+1
           elif(val2 > val1) :
             lose = lose+1

        cope = beats - lose
        newlist.append(cope)

ser = pd.Series(newlist)
df['Copeland Rule']=ser
df.sort_values(by=['Copeland Rule'],ascending=False).head(16)
# Out:
#                                                   title  A  B  C  Average  \
# 1598                               War Room, The (1993)  0  0  0      0.0
# 70                                     Anastasia (1997)  0  0  0      0.0
# 36                                       Aladdin (1992)  0  0  0      0.0
# 387                           Dazed and Confused (1993)  0  0  0      0.0
# 385                              Days of Thunder (1990)  0  0  0      0.0
# 383   Day the Sun Turned Cold, The (Tianguo niezi) (...  0  0  0      0.0
# 878                           Living in Oblivion (1995)  0  3  0      1.0
# 880                                   Local Hero (1983)  0  0  0      0.0
# 882                                 Locusts, The (1997)  0  0  0      0.0
# 1602                           Washington Square (1997)  0  0  0      0.0
# 1600                                    War, The (1994)  0  0  0      0.0
# 1292                           Secret Agent, The (1996)  0  0  0      0.0
# ...

# %%
#Bordacount
colname='A'
bor = 0
members = len(group_users)
for i in range (0,len(group_users)):
    bor += (members-i)*df[str(chr(ord(colname) + i))]
df['Borda'] = bor
df.sort_values(by=['Borda'], ascending=False).head(100)
# Out:
#                                                   title  A  B  C  Average  \
# 1221                               Red Rock West (1992)  4  5  4    4.333
# 1222                                    Ref, The (1994)  5  4  0    3.000
# 97                          Arsenic and Old Lace (1944)  5  4  0    3.000
# 1017                            Mulholland Falls (1996)  4  5  0    3.000
# 999                                Mortal Kombat (1995)  3  5  2    3.333
# ...                                                 ... .. .. ..      ...
# 532                                      Flipper (1996)  0  0  4    1.333
# 1378  Spirits of the Dead (Tre passi nel delirio) (1...  0  0  4    1.333
# 265                                      Careful (1992)  0  0  4    1.333
# 1133                             Peacemaker, The (1997)  0  2  0    0.667
# 127                               Basic Instinct (1992)  0  0  3    1.000
#
#       Least Misery  Most Pleasure  Most Respected  Multiplicative  \
# ...

# %%
import numpy as np
data=data.sort_values('user_id')
data.head(100)
#for i in data:
x=data.iloc[:,0]
y=data.iloc[:,2]
z={"user_id":x,"rating":y}
dfmade= pd.concat(z,axis = 1)
dfmade.head(100)
dfmade.to_csv("User.csv")
lengthofrating=len(dfmade)
#print(lengthofrating)

# %%
listofuser=[]
listofrating=[]
with open('User.csv', 'r+') as dfmade:
  mycsv = csv.reader(dfmade)
  mycsv = list(mycsv)
  row_count = len(mycsv)
  #print(row_count)
  #print(mycsv)
  for j in range(0,len(group_users)):
    for i in range(1,row_count-1):
        if group_users[j]==int(mycsv[i][1]):
            listofuser.append(group_users[j])
            listofrating.append(int(mycsv[i][2]))
  dfmade1 = pd.DataFrame(list(zip(listofuser, listofrating)),columns =['user_id', 'rating'])

# %%
listcorr=[]

listcorr.append(dfmade1['rating'].corr(df['Average']))
listcorr.append(dfmade1['rating'].corr(df['Least Misery']))
listcorr.append(dfmade1['rating'].corr(df['Most Pleasure']))
listcorr.append(dfmade1['rating'].corr(df['Most Respected']))
listcorr.append(dfmade1['rating'].corr(df['Multiplicative']))
listcorr.append(dfmade1['rating'].corr(df['Average Without misery']))
listcorr.append(dfmade1['rating'].corr(df['Approval Voting']))
listcorr.append(dfmade1['rating'].corr(df['Copeland Rule']))
listcorr.append(dfmade1['rating'].corr(df['Borda']))
final_list=dcg_score(listcorr)

# %%
strategy=['Average','Least Misery','Most Pleasure','Most Respected',"Multiplicative",'Average Without misery','Approval Voting','Copeland Rule','Borda']
df = pd.DataFrame(list(zip(strategy,final_list)),columns =['Strategy', 'Rank Score'])
df.head(9)
# Out:
#                  Strategy  Rank Score
# 0                 Average    2.787363
# 1            Least Misery    3.720509
# 2           Most Pleasure    3.825192
# 3          Most Respected    3.184596
# 4          Multiplicative    3.720509
# 5  Average Without misery    2.735121
# 6         Approval Voting    2.554952
# 7           Copeland Rule    1.883413
# 8                   Borda    3.782799

# %%
df.sort_values(by=['Rank Score'],ascending=False).head(9)
# Out:
#                  Strategy  Rank Score
# 2           Most Pleasure    3.825192
# 8                   Borda    3.782799
# 4          Multiplicative    3.720509
# 1            Least Misery    3.720509
# 3          Most Respected    3.184596
# 0                 Average    2.787363
# 5  Average Without misery    2.735121
# 6         Approval Voting    2.554952
# 7           Copeland Rule    1.883413
